# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
# Out:
# C:\Users\pa389\AppData\Local\Temp\ipykernel_12060\2225940201.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
df = pd.read_csv("insurance_data.csv")
df.head()
# Out:
#    age  bought_insurance
# 0   22                 0
# 1   25                 0
# 2   47                 1
# 3   52                 0
# 4   46                 1

# %%
plt.scatter(df['age'],df['bought_insurance'],color = 'red',marker = '*',s = 50)
plt.xlabel('Age')
plt.ylabel('Insurance')
plt.title('Age vs insurance')
# Out:
# Text(0.5, 1.0, 'Age vs insurance')

# %%
from sklearn.model_selection import train_test_split

# %%
x = df[['age']]
y = df['bought_insurance']

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size = 0.1,random_state = 10)

# %%
from sklearn.linear_model import LogisticRegression
obj = LogisticRegression()

# %%
obj.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
x_test
# Out:
#     age
# 7    60
# 5    56
# 18   19

# %%
y_test
# Out:
# 7     1
# 5     1
# 18    0
# Name: bought_insurance, dtype: int64

# %%
obj.predict(x_test)
# Out:
# array([1, 1, 0], dtype=int64)

# %%
obj.score(x,y)
# Out:
# 0.8888888888888888

# %%
obj.score(x_test,y_test) ##it tells the acuracy of the model
# Out:
# 1.0

# %% [markdown]
# # Excercise

# %%
df = pd.read_csv("HR_comma_sep.csv")
df.head()
# Out:
#    satisfaction_level  last_evaluation  number_project  average_montly_hours  \
# 0                0.38             0.53               2                   157
# 1                0.80             0.86               5                   262
# 2                0.11             0.88               7                   272
# 3                0.72             0.87               5                   223
# 4                0.37             0.52               2                   159
#
#    time_spend_company  Work_accident  left  promotion_last_5years Department  \
# 0                   3              0     1                      0      sales
# 1                   6              0     1                      0      sales
# 2                   4              0     1                      0      sales
# 3                   5              0     1                      0      sales
# 4                   3              0     1                      0      sales
#
#    salary
# 0     low
# 1  medium
# ...

# %%
#plt.bar(df['left'],df['salary'])

# %%
#plt.bar(df['Department',df['left']])

# %%
from sklearn.model_selection import train_test_split
x = df[['satisfaction_level','last_evaluation','average_montly_hours','time_spend_company','salary']]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 from sklearn.model_selection import train_test_split
# ----> 2 x = df[['satisfaction_level','last_evaluation','average_monthly_hours','time_spend_company','salary']]
#
# NameError: name 'df' is not defined

# %%
from sklearn.linear_model import LogisticRegression
obj1 = LogisticRegression()
