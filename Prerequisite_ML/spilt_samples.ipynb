# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv("carprices_spilt.csv")
df.head()
# Out:
#    Mileage  Age(yrs)  Sell Price($)
# 0    69000         6          18000
# 1    35000         3          34000
# 2    57000         5          26100
# 3    22500         2          40000
# 4    46000         4          31500

# %%
plt.scatter(df['Mileage'],df['Sell Price($)'],color = 'blue',s = 20)
plt.xlabel('Mileage')
plt.ylabel('Sell Price')
plt.title("Mileage vs Sell Price")
# Out:
# Text(0.5, 1.0, 'Mileage vs Sell Price')

# %%
plt.scatter(df['Age(yrs)'],df['Sell Price($)'])
plt.xlabel('Age')
plt.ylabel('Sell Price')
plt.title('Age vs Sell Price')
# Out:
# Text(0.5, 1.0, 'Age vs Sell Price')

# %%
x = df[['Mileage','Age(yrs)']]
y = df['Sell Price($)']

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=10)

# %%
x_train
# Out:
#     Mileage  Age(yrs)
# 3     22500         2
# 18    87600         8
# 13    58780         4
# 2     57000         5
# 14    82450         7
# 8     91000         8
# 17    69000         5
# 16    28000         2
# 19    52000         5
# 12    59000         5
# 11    79000         7
# 1     35000         3
# 0     69000         6
# 15    25400         3
# 4     46000         4
# 9     67000         6

# %%
len(x_train)
# Out:
# 16

# %%
from sklearn.linear_model import LinearRegression
obj = LinearRegression()

# %%
obj.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
obj.predict(x_test)
# Out:
# array([20474.0745775 , 16352.07892168, 25174.14834912, 27197.42175439])

# %%
y_test
# Out:
# 7     19300
# 10    18700
# 5     26750
# 6     32000
# Name: Sell Price($), dtype: int64

# %%
obj.score(x_train,y_train)
# Out:
# 0.9552040227313671
